# %%
## Define vaiables

i = 0.0002
L = 1020
weir_height = 2.3
weir_width = 100
Q_e = 663
q_e = Q_e / weir_width

H_e = 7.9
U_e = q_e / H_e
Uw_e = q_e / (H_e - weir_height)



dh = i * L
hw_c = 2*dh #for critical flow
uw_c = (9.81*hw_c)**0.5

print("The flow depth over the weir is:", hw_c, "m")
print("The flow velocity over the weir is:", uw_c, "m/s")
# Out:
# The flow depth over the weir is: 0.40800000000000003 m
# The flow velocity over the weir is: 2.0006199039297794 m/s

# %%
## Extreme Flow Conditions

Q_e = 663
q_e = Q_e / weir_width

Hs_e = 7.74
U_e = q_e / Hs_e
Uw_e = q_e / (Hs_e - weir_height)
Uloc_e = 2 * U_e

print("The flow velocity in extreme conditions is:", U_e, "m/s")
print("The local flow velocity in extreme conditions is:", Uloc_e, "m/s")
print("The flow velocity over the weir in extreme conditions is:", Uw_e, "m/s")

Fr_e = Uw_e / (9.81 * (Hs_e - weir_height))**0.5
print("The Froude number in extreme conditions is:", Fr_e)

r = 0.2
u_max_e = U_e * (1 + 3 * r)

print("The maximum flow velocity in extreme conditions is:", u_max_e, "m/s")
# Out:
# The flow velocity in extreme conditions is: 0.8565891472868217 m/s
# The local flow velocity in extreme conditions is: 1.7131782945736433 m/s
# The flow velocity over the weir in extreme conditions is: 1.21875 m/s
# The Froude number in extreme conditions is: 0.1668325066766034
# The maximum flow velocity in extreme conditions is: 1.3705426356589148 m/s

# %%
## Find D50 downstream

from math import log10

shields = 0.03
chezy = 50
delta = 1.65

## Create loop to find D50

D50 = 0.01 #initial guess

while abs(D50_new - D50) > 0.00001:
    D50 = D50_new
    k = 2*D50
    C = 18*log10(12*Hs_e/k)
    D50_new = (1*u_max_e**2)/(1*shields*delta*C**2)

print("The median grain size before calibration is:", D50_new, "m")

Ks = 1
Kv = 1.3

D50 = D50_new * (Kv**2 / Ks)

print("The calibrated median grain size is:", D50, "m")
# Out:
# The median grain size before calibration is: 0.00835145794739111 m
# The calibrated median grain size is: 0.014113963931090977 m

# %%
## Find D50 on the weir
import numpy as np

D50 = 0.02 #initial guess

while abs(D50_new - D50) > 0.00001:
    D50 = D50_new
    k = 2*D50
    C = 18*log10(12*(hw_c)/k)
    D50_new = (1*uw_c**2)/(1*shields*delta*C**2)

print("The median grain size on the weir before calibration is:", D50_new, "m")

phi = 41
alpha = np.degrees(np.arctan(1/1.5))

Ks_c = np.sin(np.radians(phi - alpha))/np.sin(np.radians(alpha))
Kv_c = 1.3

D50_c = D50_new * (Kv_c**2 / Ks_c)

print("The calibrated median grain size on the weir is:", D50_c, "m")

hw_c/D50_c
# Out:
# The median grain size on the weir before calibration is: 0.3056703480753065 m
# The calibrated median grain size on the weir is: 2.2520935699538938 m
# np.float64(0.18116476395265976)

# %%
## Izbash

D_izbash = (Kv_c**2 * uw_c**2) / (Ks_c * 9.81 * delta * 2.9)

print("The Izbash diameter is:", D_izbash, "m")

hw_c/D_izbash
# Out:
# The Izbash diameter is: 0.6282193947943213 m
# np.float64(0.6494546385878122)
